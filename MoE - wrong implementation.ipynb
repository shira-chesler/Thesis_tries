# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import heapq
import pickle
import os
import re
from google.colab import drive
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque
import numpy as np
import seaborn as sns

# %%
drive.mount('/content/gdrive', force_remount=True)

# Define function to load checkpoint
def load_checkpoint(model, save_dir, num_epochs, exact_checkpoint=None):
    os.makedirs(save_dir, exist_ok=True)
    checkpoint_files = [f for f in os.listdir(save_dir) if f.endswith('.pth')]
    training_finished = False

    if checkpoint_files:
        if "model_weights.pth" in checkpoint_files:
            latest_checkpoint_file = "model_weights.pth"
            training_finished = True
        elif exact_checkpoint is not None:
            latest_checkpoint_file = f"checkpoint_epoch_{exact_checkpoint}.pth"
        else:
            latest_checkpoint_file = max(checkpoint_files, key=lambda x: int(re.search(r'(\d+)', x).group()))
            print(f"Loading checkpoint: {latest_checkpoint_file}")

        model.load_state_dict(torch.load(os.path.join(save_dir, latest_checkpoint_file)))
        start_epoch = num_epochs if training_finished else int(re.search(r'(\d+)', latest_checkpoint_file).group()) + 1
    else:
        start_epoch = 0

    return start_epoch
# Out:
# Mounted at /content/gdrive

# %%
# Define ResNetTrainer
class ResNetTrainer:
    def __init__(self, x, epochs=20, batch_size=128, save_path=None):
        self.epochs = epochs
        self.batch_size = batch_size
        self.x = x  # Store the ResNet variant (e.g., 18, 34, 50, etc.)
        self.save_path = f"/content/gdrive/My Drive/checkpoints/resnet{x}_cifar100" if save_path is None else save_path
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self._prepare_data()
        self._build_model()

    def _prepare_data(self):
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        self.trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
        self.trainloader = DataLoader(self.trainset, batch_size=self.batch_size, shuffle=True, num_workers=2)
        self.testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
        self.testloader = DataLoader(self.testset, batch_size=self.batch_size, shuffle=False, num_workers=2)

    def _build_model(self):
        # Select the appropriate ResNet model based on self.x
        if self.x == 18:
            self.model = torchvision.models.resnet18(pretrained=False, num_classes=100).to(self.device)
        elif self.x == 34:
            self.model = torchvision.models.resnet34(pretrained=False, num_classes=100).to(self.device)
        elif self.x == 50:
            self.model = torchvision.models.resnet50(pretrained=False, num_classes=100).to(self.device)
        elif self.x == 101:
            self.model = torchvision.models.resnet101(pretrained=False, num_classes=100).to(self.device)
        elif self.x == 152:
            self.model = torchvision.models.resnet152(pretrained=False, num_classes=100).to(self.device)
        else:
            raise ValueError(f"ResNet variant {self.x} is not supported")

        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)

    def train(self):
        start_epoch = load_checkpoint(self.model, self.save_path, self.epochs)
        for epoch in range(start_epoch, self.epochs):
            self.model.train()
            running_loss = 0.0
            for images, labels in self.trainloader:
                images, labels = images.to(self.device), labels.to(self.device)
                self.optimizer.zero_grad()
                outputs = self.model(images)
                loss = self.criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()
                running_loss += loss.item()
            print(f"Epoch {epoch+1}/{self.epochs}, Loss: {running_loss / len(self.trainloader)}")
            checkpoint_path = os.path.join(self.save_path, f'checkpoint_epoch_{epoch + 1}.pth')
            torch.save(self.model.state_dict(), checkpoint_path)

    def load_model(self, exact_checkpoint=None):
      if os.path.exists(self.save_path) and os.path.isdir(self.save_path):
          checkpoint_files = [f for f in os.listdir(self.save_path) if f.endswith('.pth')]
          if checkpoint_files:
              if "model_weights.pth" in checkpoint_files:
                  latest_checkpoint_file = "model_weights.pth"
              elif exact_checkpoint is not None:
                  latest_checkpoint_file = f"checkpoint_epoch_{exact_checkpoint}.pth"
              else:
                  latest_checkpoint_file = max(checkpoint_files, key=lambda x: int(re.search(r'(\d+)', x).group()))
              checkpoint_path = os.path.join(self.save_path, latest_checkpoint_file)
              print(f"Loading model from {checkpoint_path}")
              self.model.load_state_dict(torch.load(checkpoint_path, map_location=self.device))
              self.model.eval()
          else:
              raise FileNotFoundError("No checkpoints found in the directory.")
      else:
          raise FileNotFoundError("Saved model directory not found.")

# %%
# Define Complexity Calculator
class ComplexityCalculator:
    def __init__(self, model, dataloader, device):
        self.model = model
        self.dataloader = dataloader
        self.device = device

    def compute_complexities(self):
        self.model.eval()
        all_confidences = []
        correct_predictions = []
        complexities = []
        confidences = []
        predictions = []
        all_images = []
        all_labels = []

        with torch.no_grad():
            for images, labels in self.dataloader:
                images, labels = images.to(self.device), labels.to(self.device)
                outputs = self.model(images)
                probabilities = torch.softmax(outputs, dim=1)
                conf, preds = torch.max(probabilities, dim=1)
                all_confidences.extend(conf.cpu().numpy())
                correct_predictions.extend((preds == labels).cpu().numpy())
                predictions.extend(preds.cpu().numpy())
                # true_labels.extend(labels.cpu().numpy())
                all_images.append(images.cpu())  # Move to CPU before storing
                all_labels.append(labels.cpu())

        # mean_confidence = sum(all_confidences) / len(all_confidences)
        # print("mean confidence is:"+ str(mean_confidence))
        test_images = torch.cat(all_images, dim=0)  # Concatenate into a single tensor
        test_labels = torch.cat(all_labels, dim=0)

        for conf, correct in zip(all_confidences, correct_predictions):
            if correct:
                complexity = 1 - (conf)
            else:
                complexity = 1 + conf
            complexities.append(complexity)
            confidences.append(conf)

        return complexities, confidences, predictions, test_images, test_labels

# %%
import json
import copy
# Load pre-trained ResNet models
# resnet18 = models.resnet18(pretrained=False)
# resnet101 = models.resnet101(pretrained=False)

def count_conv_layers(model):
    return sum(1 for layer in model.modules() if isinstance(layer, nn.Conv2d))

#def get_exit_layer(complexity, complexity_bins, num_conv_resnet18):
#    exit_index = np.digitize(complexity, complexity_bins) #-1
#    return num_conv_resnet18 + exit_index

def get_exit_layer(complexity, complexity_bins, min_layers):
    bin_index = np.digitize(complexity, complexity_bins) - 1
    return min_layers + bin_index

# Modify ResNet to allow early exiting
class EarlyExitResNet(nn.Module):
  def __init__(self, original_resnet, num_exit_layers, num_classes=100):
      super().__init__()

      self.num_exit_layers = num_exit_layers
      # original_resnet = copy.deepcopy(original_resnet)

      # Store basic parts of ResNet
      self.features = nn.Sequential()
      self.features.add_module('conv1', original_resnet.conv1)
      self.features.add_module('bn1', original_resnet.bn1)
      self.features.add_module('relu', original_resnet.relu)
      self.features.add_module('maxpool', original_resnet.maxpool)

      # Add layers up to the specified conv count
      layer_names = ['layer1', 'layer2', 'layer3', 'layer4']
      current_conv_count = 1  # Starting with 1 for the conv1 layer

      for layer_idx, layer_name in enumerate(layer_names):
          layer = getattr(original_resnet, layer_name)

          if isinstance(layer, nn.Sequential):
              for block_idx, block in enumerate(layer):
                  # Count convolutions in this block
                  block_conv_count = sum(1 for m in block.modules() if isinstance(m, nn.Conv2d))

                  # If adding this block would exceed our limit, break
                  if current_conv_count + block_conv_count > num_exit_layers:
                      break

                  self.features.add_module(f'layer{layer_idx+1}_block{block_idx}', block)
                  current_conv_count += block_conv_count

          # If we've reached our conv count limit, stop adding layers
          if current_conv_count >= num_exit_layers:
              break

      # Add global average pooling
      self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

      # Initialize FC to None - we'll set it after determining input size
      self.fc = None
      self.num_classes = num_classes
      self.in_features = None  # Store the input features for the FC layer

  def forward(self, x):
      x = self.features(x)
      x = self.avgpool(x)
      x = torch.flatten(x, 1)

      if self.fc is None:
          self.in_features = x.shape[1]
          self.fc = nn.Linear(self.in_features, self.num_classes).to(x.device)
          nn.init.kaiming_normal_(self.fc.weight, mode='fan_out', nonlinearity='relu')
          if self.fc.bias is not None:
              nn.init.constant_(self.fc.bias, 0)
          # print(f"Created new FC layer with input size {self.in_features} and output size {self.num_classes}")

      x = self.fc(x)
      return x

  def save_model(self, save_path, epoch=None):
      """Save the model weights to the specified path."""
      os.makedirs(save_path, exist_ok=True)

      if epoch is not None:
          checkpoint_path = os.path.join(save_path, f"exit_{self.num_exit_layers}_epoch_{epoch}.pth")
      else: #
          checkpoint_path = os.path.join(save_path, f"exit_{self.num_exit_layers}_weights.pth") #

      # Save model state dictionary
      torch.save(self.state_dict(), checkpoint_path)
      print(f"Model saved to {checkpoint_path}")

      # Also save the input feature dimension for the FC layer
      # config_path = os.path.join(save_path, f"exit_{self.num_exit_layers}_config.json")
      # config = {
      #     "num_exit_layers": self.num_exit_layers,
      #     "in_features": self.in_features,
      #     "num_classes": self.num_classes
      # }
      # with open(config_path, 'w') as f:
      #     json.dump(config, f)
      # print(f"Model configuration saved to {config_path}")

  @classmethod
  def load_model(cls, original_resnet, save_path, num_exit_layers, device='cuda', exact_checkpoint=None):
      """Load a model from the specified path."""
      # First, load the configuration
      # config_path = os.path.join(save_path, f"exit_{num_exit_layers}_config.json")
      # if os.path.exists(config_path):
      #     with open(config_path, 'r') as f:
      #         config = json.load(f)
      #     num_classes = config.get("num_classes", 100)
      # else:
      #     print("No configuration file found, using default values.")
      #     num_classes = 100

      # Create the model
      model = cls(original_resnet, num_exit_layers, 100) # CIFAR-100

      # Initialize the FC layer with a dummy forward pass
      dummy_input = torch.randn(1, 3, 32, 32).to(device)  # CIFAR-100 images
      _ = model(dummy_input)

      # Find the checkpoint file
      if os.path.exists(save_path) and os.path.isdir(save_path):
          checkpoint_files = [f for f in os.listdir(save_path)
                            if f.startswith(f"exit_{num_exit_layers}") and f.endswith('.pth')]

          if checkpoint_files:
              if f"exit_{num_exit_layers}_weights.pth" in checkpoint_files:
                  checkpoint_file = f"exit_{num_exit_layers}_weights.pth"
              elif exact_checkpoint is not None:
                  checkpoint_file = f"exit_{num_exit_layers}_epoch_{exact_checkpoint}.pth"
              else:
                  # Get the latest epoch checkpoint
                  epoch_checkpoints = [f for f in checkpoint_files if "epoch" in f]
                  if epoch_checkpoints:
                      checkpoint_file = max(epoch_checkpoints,
                                          key=lambda x: int(re.search(r'epoch_(\d+)', x).group(1)))
                  else:
                      checkpoint_file = checkpoint_files[0]

              checkpoint_path = os.path.join(save_path, checkpoint_file)
              print(f"Loading model from {checkpoint_path}")
              model.load_state_dict(torch.load(checkpoint_path, map_location=device))
              model.eval()

              match = re.search(r'epoch_(\d+)', checkpoint_file)
              start_epoch = int(match.group(1)) + 1 if match else 0

              return model.to(device), start_epoch
          else:
              raise FileNotFoundError(f"No checkpoints found for exit layer {num_exit_layers}.")
      else:
          raise FileNotFoundError("Saved model directory not found.")

def fine_tune_early_exit_model(original_model, train_loader, num_exit_layers, save_path,start_epoch,
                               num_classes=100, device='cuda', epochs=20, lr=0.001):
    # Create early exit model
    early_exit_model = EarlyExitResNet(original_model, num_exit_layers, num_classes).to(device)

    # Initialize the FC layer with a forward pass
    dummy_input = torch.randn(1, 3, 32, 32).to(device)  # Assuming CIFAR-100 images
    _ = early_exit_model(dummy_input)

    # Freeze all layers except the final FC layer
    for param in early_exit_model.parameters():
        param.requires_grad = False

    # Ensure the final FC layer's parameters are trainable
    for param in early_exit_model.fc.parameters():
        param.requires_grad = True

    # Set up optimizer and loss function
    optimizer = torch.optim.Adam(early_exit_model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    # Fine-tuning loop
    early_exit_model.train()
    for epoch in range(start_epoch, epochs):
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = early_exit_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        # Print statistics
        print(f'Epoch {epoch+1}/{epochs}, Loss: {running_loss/len(train_loader):.4f}, '
              f'Acc: {100.*correct/total:.2f}%')

        # Save checkpoint
        early_exit_model.save_model(save_path, epoch=epoch+1)

    # Save final model
    early_exit_model.save_model(save_path) #

    return early_exit_model

# %%
# Apply early exit logic to test images
complexity_trainer = ResNetTrainer(34, epochs=20, batch_size=128, save_path=f"/content/gdrive/My Drive/checkpoints/resnet34_cifar100")
complexity_trainer.train()
complexity_trainer.load_model(exact_checkpoint=20)

test_loader = DataLoader(complexity_trainer.testset, batch_size=128, shuffle=False, num_workers=2)
complexity_calculator = ComplexityCalculator(complexity_trainer.model, test_loader, complexity_trainer.device)
complexities, confidences, predictions, test_images, test_labels = complexity_calculator.compute_complexities()
complexities = np.array(complexities)

resnet101 = ResNetTrainer(101, epochs=100, batch_size=128, save_path=f"/content/gdrive/My Drive/checkpoints/resnet101_cifar100")
resnet101.train()
resnet101.load_model(exact_checkpoint=100)

resnet18 = ResNetTrainer(18, epochs=100, batch_size=128, save_path=f"/content/gdrive/My Drive/checkpoints/resnet18_cifar100")
resnet18.train()
resnet18.load_model()

num_conv_resnet18 = count_conv_layers(resnet18.model)
num_conv_resnet101 = count_conv_layers(resnet101.model)

x = num_conv_resnet101 - num_conv_resnet18
complexity_bins = np.linspace(0, 2, x + 1)


if isinstance(test_images, torch.Tensor):
    batch_images = test_images.to(resnet101.device)
else:
    batch_images = torch.stack(test_images).to(resnet101.device)

exit_layers = [get_exit_layer(c, complexity_bins, num_conv_resnet18) for c in complexities]

# Define save path for early exit models
early_exit_save_path = "/content/gdrive/My Drive/checkpoints/early_exit_models"
os.makedirs(early_exit_save_path, exist_ok=True)

# First, identify the unique exit layers
unique_exit_layers = sorted(set(exit_layers))

# Create a dictionary to store the fine-tuned models
fine_tuned_models = {}

# Fine-tune a model for each unique exit layer
for exit_layer in unique_exit_layers:
    try:
        # Try to load existing model
        print(f"Attempting to load model for exit layer {exit_layer}")
        model, latest_epoch = EarlyExitResNet.load_model(
            resnet101.model,
            early_exit_save_path,
            exit_layer,
            device=resnet101.device
        )
        fine_tune_early_exit_model(model, torch.utils.data.DataLoader(resnet101.trainset, batch_size=128, shuffle=True), exit_layer, early_exit_save_path, latest_epoch, epochs=15)
        fine_tuned_models[exit_layer] = model
        print(f"Successfully loaded model for exit layer {exit_layer}")
    except FileNotFoundError:
        # Fine-tune new model if not found
        print(f"Fine-tuning new model for exit layer {exit_layer}")
        fine_tuned_models[exit_layer] = fine_tune_early_exit_model(
            resnet101.model,
            torch.utils.data.DataLoader(resnet101.trainset, batch_size=128, shuffle=True),
            exit_layer,
            early_exit_save_path,
            start_epoch=0
        )

# Evaluate each fine-tuned model on the appropriate test samples
for unique_exit in unique_exit_layers:
    indices = [i for i, e in enumerate(exit_layers) if e == unique_exit]
    if not indices:
        continue

    sub_batch = batch_images[indices]
    sub_batch_labels = torch.tensor([test_labels[i] for i in indices]).to(resnet101.device)

    model = fine_tuned_models[unique_exit]
    model.eval()

    with torch.no_grad():
        outputs = model(sub_batch)

    _, predicted = torch.max(outputs.data, 1)
    correct = (predicted == sub_batch_labels).sum().item()
    accuracy = correct / len(indices)
    print(f"Exit layer {unique_exit} accuracy: {accuracy:.4f}")
# Out:
# Loading checkpoint: checkpoint_epoch_100.pth
# Loading model from /content/gdrive/My Drive/checkpoints/resnet34_cifar100/checkpoint_epoch_20.pth
# Loading checkpoint: checkpoint_epoch_100.pth
# Loading model from /content/gdrive/My Drive/checkpoints/resnet101_cifar100/checkpoint_epoch_100.pth
# Loading checkpoint: checkpoint_epoch_100.pth
# Loading model from /content/gdrive/My Drive/checkpoints/resnet18_cifar100/checkpoint_epoch_100.pth
# Attempting to load model for exit layer 20
# Fine-tuning new model for exit layer 20
# Epoch 1/20, Loss: 4.3362, Acc: 9.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_1.pth
# Epoch 2/20, Loss: 3.5796, Acc: 16.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_2.pth
# Epoch 3/20, Loss: 3.3778, Acc: 20.31%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_3.pth
# Epoch 4/20, Loss: 3.2562, Acc: 22.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_4.pth
# Epoch 5/20, Loss: 3.1699, Acc: 23.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_5.pth
# Epoch 6/20, Loss: 3.1067, Acc: 25.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_6.pth
# Epoch 7/20, Loss: 3.0593, Acc: 25.98%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_7.pth
# Epoch 8/20, Loss: 3.0131, Acc: 26.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_8.pth
# Epoch 9/20, Loss: 2.9683, Acc: 27.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_9.pth
# Epoch 10/20, Loss: 2.9404, Acc: 28.51%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_10.pth
# Epoch 11/20, Loss: 2.9140, Acc: 28.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_11.pth
# Epoch 12/20, Loss: 2.8852, Acc: 29.34%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_12.pth
# Epoch 13/20, Loss: 2.8611, Acc: 29.89%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_13.pth
# Epoch 14/20, Loss: 2.8393, Acc: 30.27%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_14.pth
# Epoch 15/20, Loss: 2.8186, Acc: 30.58%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_15.pth
# Epoch 16/20, Loss: 2.8048, Acc: 30.93%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_16.pth
# Epoch 17/20, Loss: 2.7866, Acc: 31.28%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_17.pth
# Epoch 18/20, Loss: 2.7734, Acc: 31.51%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_18.pth
# Epoch 19/20, Loss: 2.7541, Acc: 31.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_19.pth
# Epoch 20/20, Loss: 2.7442, Acc: 32.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_20_weights.pth
# Attempting to load model for exit layer 21
# Fine-tuning new model for exit layer 21
# Epoch 1/20, Loss: 4.4088, Acc: 8.93%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_1.pth
# Epoch 2/20, Loss: 3.5662, Acc: 16.92%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_2.pth
# Epoch 3/20, Loss: 3.3684, Acc: 20.17%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_3.pth
# Epoch 4/20, Loss: 3.2355, Acc: 22.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_4.pth
# Epoch 5/20, Loss: 3.1560, Acc: 24.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_5.pth
# Epoch 6/20, Loss: 3.0841, Acc: 25.41%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_6.pth
# Epoch 7/20, Loss: 3.0262, Acc: 26.66%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_7.pth
# Epoch 8/20, Loss: 2.9778, Acc: 27.55%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_8.pth
# Epoch 9/20, Loss: 2.9344, Acc: 28.43%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_9.pth
# Epoch 10/20, Loss: 2.9051, Acc: 28.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_10.pth
# Epoch 11/20, Loss: 2.8739, Acc: 29.50%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_11.pth
# Epoch 12/20, Loss: 2.8449, Acc: 30.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_12.pth
# Epoch 13/20, Loss: 2.8257, Acc: 30.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_13.pth
# Epoch 14/20, Loss: 2.8012, Acc: 30.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_14.pth
# Epoch 15/20, Loss: 2.7803, Acc: 31.35%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_15.pth
# Epoch 16/20, Loss: 2.7603, Acc: 31.64%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_16.pth
# Epoch 17/20, Loss: 2.7410, Acc: 32.26%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_17.pth
# Epoch 18/20, Loss: 2.7273, Acc: 32.36%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_18.pth
# Epoch 19/20, Loss: 2.7036, Acc: 33.04%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_19.pth
# Epoch 20/20, Loss: 2.6953, Acc: 33.21%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_21_weights.pth
# Attempting to load model for exit layer 22
# Fine-tuning new model for exit layer 22
# Epoch 1/20, Loss: 4.4230, Acc: 9.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_1.pth
# Epoch 2/20, Loss: 3.5772, Acc: 16.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_2.pth
# Epoch 3/20, Loss: 3.3681, Acc: 20.54%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_3.pth
# Epoch 4/20, Loss: 3.2375, Acc: 22.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_4.pth
# Epoch 5/20, Loss: 3.1500, Acc: 24.25%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_5.pth
# Epoch 6/20, Loss: 3.0813, Acc: 25.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_6.pth
# Epoch 7/20, Loss: 3.0274, Acc: 26.44%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_7.pth
# Epoch 8/20, Loss: 2.9797, Acc: 27.60%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_8.pth
# Epoch 9/20, Loss: 2.9415, Acc: 28.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_9.pth
# Epoch 10/20, Loss: 2.9085, Acc: 28.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_10.pth
# Epoch 11/20, Loss: 2.8714, Acc: 29.51%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_11.pth
# Epoch 12/20, Loss: 2.8459, Acc: 30.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_12.pth
# Epoch 13/20, Loss: 2.8241, Acc: 30.39%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_13.pth
# Epoch 14/20, Loss: 2.7988, Acc: 30.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_14.pth
# Epoch 15/20, Loss: 2.7800, Acc: 31.18%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_15.pth
# Epoch 16/20, Loss: 2.7610, Acc: 31.73%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_16.pth
# Epoch 17/20, Loss: 2.7429, Acc: 31.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_17.pth
# Epoch 18/20, Loss: 2.7246, Acc: 32.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_18.pth
# Epoch 19/20, Loss: 2.7106, Acc: 32.65%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_19.pth
# Epoch 20/20, Loss: 2.6941, Acc: 33.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_22_weights.pth
# Attempting to load model for exit layer 23
# Fine-tuning new model for exit layer 23
# Epoch 1/20, Loss: 4.4841, Acc: 8.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_1.pth
# Epoch 2/20, Loss: 3.5854, Acc: 16.63%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_2.pth
# Epoch 3/20, Loss: 3.3733, Acc: 20.43%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_3.pth
# Epoch 4/20, Loss: 3.2414, Acc: 22.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_4.pth
# Epoch 5/20, Loss: 3.1507, Acc: 24.63%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_5.pth
# Epoch 6/20, Loss: 3.0841, Acc: 25.56%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_6.pth
# Epoch 7/20, Loss: 3.0270, Acc: 26.56%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_7.pth
# Epoch 8/20, Loss: 2.9808, Acc: 27.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_8.pth
# Epoch 9/20, Loss: 2.9469, Acc: 28.36%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_9.pth
# Epoch 10/20, Loss: 2.9096, Acc: 28.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_10.pth
# Epoch 11/20, Loss: 2.8758, Acc: 29.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_11.pth
# Epoch 12/20, Loss: 2.8493, Acc: 29.93%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_12.pth
# Epoch 13/20, Loss: 2.8239, Acc: 30.64%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_13.pth
# Epoch 14/20, Loss: 2.8007, Acc: 31.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_14.pth
# Epoch 15/20, Loss: 2.7798, Acc: 31.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_15.pth
# Epoch 16/20, Loss: 2.7525, Acc: 32.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_16.pth
# Epoch 17/20, Loss: 2.7431, Acc: 31.99%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_17.pth
# Epoch 18/20, Loss: 2.7268, Acc: 32.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_18.pth
# Epoch 19/20, Loss: 2.7094, Acc: 32.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_19.pth
# Epoch 20/20, Loss: 2.6941, Acc: 33.17%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_23_weights.pth
# Attempting to load model for exit layer 24
# Fine-tuning new model for exit layer 24
# Epoch 1/20, Loss: 4.4721, Acc: 8.46%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_1.pth
# Epoch 2/20, Loss: 3.5709, Acc: 16.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_2.pth
# Epoch 3/20, Loss: 3.3483, Acc: 20.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_3.pth
# Epoch 4/20, Loss: 3.2136, Acc: 22.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_4.pth
# Epoch 5/20, Loss: 3.1292, Acc: 24.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_5.pth
# Epoch 6/20, Loss: 3.0518, Acc: 26.02%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_6.pth
# Epoch 7/20, Loss: 2.9940, Acc: 27.22%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_7.pth
# Epoch 8/20, Loss: 2.9474, Acc: 28.10%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_8.pth
# Epoch 9/20, Loss: 2.9050, Acc: 28.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_9.pth
# Epoch 10/20, Loss: 2.8721, Acc: 29.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_10.pth
# Epoch 11/20, Loss: 2.8379, Acc: 30.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_11.pth
# Epoch 12/20, Loss: 2.8094, Acc: 30.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_12.pth
# Epoch 13/20, Loss: 2.7848, Acc: 31.17%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_13.pth
# Epoch 14/20, Loss: 2.7581, Acc: 31.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_14.pth
# Epoch 15/20, Loss: 2.7407, Acc: 31.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_15.pth
# Epoch 16/20, Loss: 2.7231, Acc: 32.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_16.pth
# Epoch 17/20, Loss: 2.7011, Acc: 33.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_17.pth
# Epoch 18/20, Loss: 2.6855, Acc: 33.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_18.pth
# Epoch 19/20, Loss: 2.6649, Acc: 33.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_19.pth
# Epoch 20/20, Loss: 2.6459, Acc: 33.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_24_weights.pth
# Attempting to load model for exit layer 25
# Fine-tuning new model for exit layer 25
# Epoch 1/20, Loss: 4.4861, Acc: 8.31%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_1.pth
# Epoch 2/20, Loss: 3.5751, Acc: 16.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_2.pth
# Epoch 3/20, Loss: 3.3511, Acc: 20.61%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_3.pth
# Epoch 4/20, Loss: 3.2168, Acc: 23.11%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_4.pth
# Epoch 5/20, Loss: 3.1196, Acc: 25.03%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_5.pth
# Epoch 6/20, Loss: 3.0444, Acc: 26.36%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_6.pth
# Epoch 7/20, Loss: 2.9930, Acc: 27.38%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_7.pth
# Epoch 8/20, Loss: 2.9449, Acc: 28.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_8.pth
# Epoch 9/20, Loss: 2.9038, Acc: 28.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_9.pth
# Epoch 10/20, Loss: 2.8673, Acc: 29.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_10.pth
# Epoch 11/20, Loss: 2.8328, Acc: 30.38%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_11.pth
# Epoch 12/20, Loss: 2.8062, Acc: 30.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_12.pth
# Epoch 13/20, Loss: 2.7812, Acc: 31.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_13.pth
# Epoch 14/20, Loss: 2.7594, Acc: 31.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_14.pth
# Epoch 15/20, Loss: 2.7376, Acc: 32.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_15.pth
# Epoch 16/20, Loss: 2.7182, Acc: 32.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_16.pth
# Epoch 17/20, Loss: 2.6975, Acc: 33.19%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_17.pth
# Epoch 18/20, Loss: 2.6807, Acc: 33.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_18.pth
# Epoch 19/20, Loss: 2.6670, Acc: 33.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_19.pth
# Epoch 20/20, Loss: 2.6463, Acc: 34.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_25_weights.pth
# Attempting to load model for exit layer 26
# Fine-tuning new model for exit layer 26
# Epoch 1/20, Loss: 4.4771, Acc: 8.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_1.pth
# Epoch 2/20, Loss: 3.5631, Acc: 16.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_2.pth
# Epoch 3/20, Loss: 3.3427, Acc: 20.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_3.pth
# Epoch 4/20, Loss: 3.2106, Acc: 23.18%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_4.pth
# Epoch 5/20, Loss: 3.1140, Acc: 25.10%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_5.pth
# Epoch 6/20, Loss: 3.0489, Acc: 26.27%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_6.pth
# Epoch 7/20, Loss: 2.9877, Acc: 27.37%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_7.pth
# Epoch 8/20, Loss: 2.9413, Acc: 28.21%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_8.pth
# Epoch 9/20, Loss: 2.8991, Acc: 29.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_9.pth
# Epoch 10/20, Loss: 2.8585, Acc: 30.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_10.pth
# Epoch 11/20, Loss: 2.8280, Acc: 30.34%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_11.pth
# Epoch 12/20, Loss: 2.8083, Acc: 30.75%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_12.pth
# Epoch 13/20, Loss: 2.7775, Acc: 31.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_13.pth
# Epoch 14/20, Loss: 2.7541, Acc: 31.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_14.pth
# Epoch 15/20, Loss: 2.7362, Acc: 32.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_15.pth
# Epoch 16/20, Loss: 2.7150, Acc: 32.69%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_16.pth
# Epoch 17/20, Loss: 2.6985, Acc: 33.05%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_17.pth
# Epoch 18/20, Loss: 2.6799, Acc: 33.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_18.pth
# Epoch 19/20, Loss: 2.6655, Acc: 33.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_19.pth
# Epoch 20/20, Loss: 2.6481, Acc: 33.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_26_weights.pth
# Attempting to load model for exit layer 27
# Fine-tuning new model for exit layer 27
# Epoch 1/20, Loss: 4.4399, Acc: 8.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_1.pth
# Epoch 2/20, Loss: 3.5592, Acc: 17.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_2.pth
# Epoch 3/20, Loss: 3.3397, Acc: 20.70%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_3.pth
# Epoch 4/20, Loss: 3.2081, Acc: 23.11%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_4.pth
# Epoch 5/20, Loss: 3.1161, Acc: 24.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_5.pth
# Epoch 6/20, Loss: 3.0405, Acc: 26.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_6.pth
# Epoch 7/20, Loss: 2.9879, Acc: 27.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_7.pth
# Epoch 8/20, Loss: 2.9313, Acc: 28.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_8.pth
# Epoch 9/20, Loss: 2.8997, Acc: 29.05%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_9.pth
# Epoch 10/20, Loss: 2.8639, Acc: 29.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_10.pth
# Epoch 11/20, Loss: 2.8310, Acc: 30.54%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_11.pth
# Epoch 12/20, Loss: 2.8038, Acc: 30.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_12.pth
# Epoch 13/20, Loss: 2.7734, Acc: 31.73%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_13.pth
# Epoch 14/20, Loss: 2.7538, Acc: 31.77%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_14.pth
# Epoch 15/20, Loss: 2.7362, Acc: 32.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_15.pth
# Epoch 16/20, Loss: 2.7145, Acc: 32.76%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_16.pth
# Epoch 17/20, Loss: 2.6950, Acc: 33.10%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_17.pth
# Epoch 18/20, Loss: 2.6750, Acc: 33.46%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_18.pth
# Epoch 19/20, Loss: 2.6646, Acc: 33.55%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_19.pth
# Epoch 20/20, Loss: 2.6480, Acc: 34.11%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_27_weights.pth
# Attempting to load model for exit layer 28
# Fine-tuning new model for exit layer 28
# Epoch 1/20, Loss: 4.4965, Acc: 13.10%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_1.pth
# Epoch 2/20, Loss: 3.2424, Acc: 25.22%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_2.pth
# Epoch 3/20, Loss: 2.9033, Acc: 30.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_3.pth
# Epoch 4/20, Loss: 2.6839, Acc: 34.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_4.pth
# Epoch 5/20, Loss: 2.5333, Acc: 37.19%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_5.pth
# Epoch 6/20, Loss: 2.4127, Acc: 39.42%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_6.pth
# Epoch 7/20, Loss: 2.3169, Acc: 41.34%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_7.pth
# Epoch 8/20, Loss: 2.2362, Acc: 43.14%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_8.pth
# Epoch 9/20, Loss: 2.1669, Acc: 44.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_9.pth
# Epoch 10/20, Loss: 2.1109, Acc: 45.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_10.pth
# Epoch 11/20, Loss: 2.0523, Acc: 46.75%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_11.pth
# Epoch 12/20, Loss: 2.0054, Acc: 47.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_12.pth
# Epoch 13/20, Loss: 1.9607, Acc: 49.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_13.pth
# Epoch 14/20, Loss: 1.9207, Acc: 49.72%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_14.pth
# Epoch 15/20, Loss: 1.8879, Acc: 50.76%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_15.pth
# Epoch 16/20, Loss: 1.8491, Acc: 51.38%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_16.pth
# Epoch 17/20, Loss: 1.8181, Acc: 52.25%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_17.pth
# Epoch 18/20, Loss: 1.7878, Acc: 52.92%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_18.pth
# Epoch 19/20, Loss: 1.7600, Acc: 53.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_19.pth
# Epoch 20/20, Loss: 1.7372, Acc: 53.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_28_weights.pth
# Attempting to load model for exit layer 29
# Fine-tuning new model for exit layer 29
# Epoch 1/20, Loss: 4.5850, Acc: 12.55%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_1.pth
# Epoch 2/20, Loss: 3.2876, Acc: 24.69%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_2.pth
# Epoch 3/20, Loss: 2.9243, Acc: 30.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_3.pth
# Epoch 4/20, Loss: 2.6998, Acc: 34.22%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_4.pth
# Epoch 5/20, Loss: 2.5492, Acc: 36.89%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_5.pth
# Epoch 6/20, Loss: 2.4254, Acc: 39.07%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_6.pth
# Epoch 7/20, Loss: 2.3213, Acc: 41.28%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_7.pth
# Epoch 8/20, Loss: 2.2407, Acc: 42.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_8.pth
# Epoch 9/20, Loss: 2.1758, Acc: 44.45%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_9.pth
# Epoch 10/20, Loss: 2.1107, Acc: 45.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_10.pth
# Epoch 11/20, Loss: 2.0542, Acc: 46.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_11.pth
# Epoch 12/20, Loss: 2.0073, Acc: 47.69%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_12.pth
# Epoch 13/20, Loss: 1.9613, Acc: 49.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_13.pth
# Epoch 14/20, Loss: 1.9218, Acc: 49.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_14.pth
# Epoch 15/20, Loss: 1.8837, Acc: 50.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_15.pth
# Epoch 16/20, Loss: 1.8572, Acc: 51.42%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_16.pth
# Epoch 17/20, Loss: 1.8223, Acc: 52.13%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_17.pth
# Epoch 18/20, Loss: 1.7908, Acc: 52.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_18.pth
# Epoch 19/20, Loss: 1.7636, Acc: 53.42%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_19.pth
# Epoch 20/20, Loss: 1.7390, Acc: 54.04%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_29_weights.pth
# Attempting to load model for exit layer 30
# Fine-tuning new model for exit layer 30
# Epoch 1/20, Loss: 4.5576, Acc: 12.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_1.pth
# Epoch 2/20, Loss: 3.2654, Acc: 24.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_2.pth
# Epoch 3/20, Loss: 2.9057, Acc: 30.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_3.pth
# Epoch 4/20, Loss: 2.6970, Acc: 33.99%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_4.pth
# Epoch 5/20, Loss: 2.5370, Acc: 37.13%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_5.pth
# Epoch 6/20, Loss: 2.4171, Acc: 39.61%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_6.pth
# Epoch 7/20, Loss: 2.3207, Acc: 41.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_7.pth
# Epoch 8/20, Loss: 2.2408, Acc: 42.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_8.pth
# Epoch 9/20, Loss: 2.1626, Acc: 44.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_9.pth
# Epoch 10/20, Loss: 2.1077, Acc: 45.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_10.pth
# Epoch 11/20, Loss: 2.0551, Acc: 46.73%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_11.pth
# Epoch 12/20, Loss: 2.0030, Acc: 48.05%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_12.pth
# Epoch 13/20, Loss: 1.9553, Acc: 49.16%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_13.pth
# Epoch 14/20, Loss: 1.9249, Acc: 49.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_14.pth
# Epoch 15/20, Loss: 1.8845, Acc: 50.72%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_15.pth
# Epoch 16/20, Loss: 1.8484, Acc: 51.71%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_16.pth
# Epoch 17/20, Loss: 1.8172, Acc: 52.18%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_17.pth
# Epoch 18/20, Loss: 1.7876, Acc: 53.04%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_18.pth
# Epoch 19/20, Loss: 1.7657, Acc: 53.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_19.pth
# Epoch 20/20, Loss: 1.7422, Acc: 53.83%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_30_weights.pth
# Attempting to load model for exit layer 31
# Fine-tuning new model for exit layer 31
# Epoch 1/20, Loss: 4.5174, Acc: 13.38%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_1.pth
# Epoch 2/20, Loss: 3.0881, Acc: 28.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_2.pth
# Epoch 3/20, Loss: 2.6842, Acc: 34.55%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_3.pth
# Epoch 4/20, Loss: 2.4488, Acc: 38.70%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_4.pth
# Epoch 5/20, Loss: 2.2755, Acc: 42.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_5.pth
# Epoch 6/20, Loss: 2.1475, Acc: 44.50%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_6.pth
# Epoch 7/20, Loss: 2.0432, Acc: 46.98%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_7.pth
# Epoch 8/20, Loss: 1.9559, Acc: 48.60%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_8.pth
# Epoch 9/20, Loss: 1.8821, Acc: 50.28%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_9.pth
# Epoch 10/20, Loss: 1.8166, Acc: 51.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_10.pth
# Epoch 11/20, Loss: 1.7623, Acc: 53.13%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_11.pth
# Epoch 12/20, Loss: 1.7086, Acc: 54.02%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_12.pth
# Epoch 13/20, Loss: 1.6606, Acc: 55.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_13.pth
# Epoch 14/20, Loss: 1.6183, Acc: 56.34%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_14.pth
# Epoch 15/20, Loss: 1.5769, Acc: 57.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_15.pth
# Epoch 16/20, Loss: 1.5471, Acc: 57.81%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_16.pth
# Epoch 17/20, Loss: 1.5153, Acc: 58.70%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_17.pth
# Epoch 18/20, Loss: 1.4835, Acc: 59.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_18.pth
# Epoch 19/20, Loss: 1.4531, Acc: 59.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_19.pth
# Epoch 20/20, Loss: 1.4236, Acc: 61.00%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_31_weights.pth
# Attempting to load model for exit layer 32
# Fine-tuning new model for exit layer 32
# Epoch 1/20, Loss: 4.5549, Acc: 13.35%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_1.pth
# Epoch 2/20, Loss: 3.0824, Acc: 27.83%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_2.pth
# Epoch 3/20, Loss: 2.6742, Acc: 34.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_3.pth
# Epoch 4/20, Loss: 2.4380, Acc: 38.64%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_4.pth
# Epoch 5/20, Loss: 2.2707, Acc: 41.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_5.pth
# Epoch 6/20, Loss: 2.1405, Acc: 44.37%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_6.pth
# Epoch 7/20, Loss: 2.0384, Acc: 47.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_7.pth
# Epoch 8/20, Loss: 1.9491, Acc: 48.70%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_8.pth
# Epoch 9/20, Loss: 1.8691, Acc: 50.44%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_9.pth
# Epoch 10/20, Loss: 1.8103, Acc: 51.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_10.pth
# Epoch 11/20, Loss: 1.7463, Acc: 53.11%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_11.pth
# Epoch 12/20, Loss: 1.6938, Acc: 54.58%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_12.pth
# Epoch 13/20, Loss: 1.6552, Acc: 55.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_13.pth
# Epoch 14/20, Loss: 1.6102, Acc: 56.61%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_14.pth
# Epoch 15/20, Loss: 1.5769, Acc: 57.43%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_15.pth
# Epoch 16/20, Loss: 1.5431, Acc: 57.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_16.pth
# Epoch 17/20, Loss: 1.5091, Acc: 58.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_17.pth
# Epoch 18/20, Loss: 1.4773, Acc: 59.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_18.pth
# Epoch 19/20, Loss: 1.4498, Acc: 60.35%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_19.pth
# Epoch 20/20, Loss: 1.4229, Acc: 61.04%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_32_weights.pth
# Attempting to load model for exit layer 33
# Fine-tuning new model for exit layer 33
# Epoch 1/20, Loss: 4.5275, Acc: 13.19%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_1.pth
# Epoch 2/20, Loss: 3.0856, Acc: 27.83%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_2.pth
# Epoch 3/20, Loss: 2.6842, Acc: 34.46%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_3.pth
# Epoch 4/20, Loss: 2.4433, Acc: 38.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_4.pth
# Epoch 5/20, Loss: 2.2736, Acc: 42.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_5.pth
# Epoch 6/20, Loss: 2.1358, Acc: 44.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_6.pth
# Epoch 7/20, Loss: 2.0435, Acc: 46.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_7.pth
# Epoch 8/20, Loss: 1.9490, Acc: 48.84%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_8.pth
# Epoch 9/20, Loss: 1.8767, Acc: 50.35%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_9.pth
# Epoch 10/20, Loss: 1.8147, Acc: 51.83%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_10.pth
# Epoch 11/20, Loss: 1.7500, Acc: 52.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_11.pth
# Epoch 12/20, Loss: 1.7043, Acc: 54.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_12.pth
# Epoch 13/20, Loss: 1.6557, Acc: 55.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_13.pth
# Epoch 14/20, Loss: 1.6165, Acc: 56.34%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_14.pth
# Epoch 15/20, Loss: 1.5761, Acc: 57.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_15.pth
# Epoch 16/20, Loss: 1.5422, Acc: 58.05%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_16.pth
# Epoch 17/20, Loss: 1.5076, Acc: 59.03%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_17.pth
# Epoch 18/20, Loss: 1.4836, Acc: 59.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_18.pth
# Epoch 19/20, Loss: 1.4463, Acc: 60.36%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_19.pth
# Epoch 20/20, Loss: 1.4283, Acc: 60.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_33_weights.pth
# Attempting to load model for exit layer 34
# Fine-tuning new model for exit layer 34
# Epoch 1/20, Loss: 4.6755, Acc: 12.31%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_1.pth
# Epoch 2/20, Loss: 3.1073, Acc: 27.54%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_2.pth
# Epoch 3/20, Loss: 2.6858, Acc: 34.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_3.pth
# Epoch 4/20, Loss: 2.4301, Acc: 38.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_4.pth
# Epoch 5/20, Loss: 2.2502, Acc: 42.10%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_5.pth
# Epoch 6/20, Loss: 2.1149, Acc: 45.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_6.pth
# Epoch 7/20, Loss: 2.0016, Acc: 47.64%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_7.pth
# Epoch 8/20, Loss: 1.9159, Acc: 49.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_8.pth
# Epoch 9/20, Loss: 1.8352, Acc: 51.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_9.pth
# Epoch 10/20, Loss: 1.7641, Acc: 52.74%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_10.pth
# Epoch 11/20, Loss: 1.7112, Acc: 53.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_11.pth
# Epoch 12/20, Loss: 1.6580, Acc: 55.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_12.pth
# Epoch 13/20, Loss: 1.6106, Acc: 56.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_13.pth
# Epoch 14/20, Loss: 1.5646, Acc: 57.39%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_14.pth
# Epoch 15/20, Loss: 1.5222, Acc: 58.23%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_15.pth
# Epoch 16/20, Loss: 1.4854, Acc: 59.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_16.pth
# Epoch 17/20, Loss: 1.4545, Acc: 59.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_17.pth
# Epoch 18/20, Loss: 1.4251, Acc: 60.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_18.pth
# Epoch 19/20, Loss: 1.3907, Acc: 61.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_19.pth
# Epoch 20/20, Loss: 1.3631, Acc: 62.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_34_weights.pth
# Attempting to load model for exit layer 35
# Fine-tuning new model for exit layer 35
# Epoch 1/20, Loss: 4.6572, Acc: 12.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_1.pth
# Epoch 2/20, Loss: 3.1081, Acc: 27.46%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_2.pth
# Epoch 3/20, Loss: 2.6779, Acc: 34.65%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_3.pth
# Epoch 4/20, Loss: 2.4289, Acc: 38.93%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_4.pth
# Epoch 5/20, Loss: 2.2452, Acc: 42.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_5.pth
# Epoch 6/20, Loss: 2.1106, Acc: 44.96%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_6.pth
# Epoch 7/20, Loss: 2.0072, Acc: 47.30%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_7.pth
# Epoch 8/20, Loss: 1.9104, Acc: 49.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_8.pth
# Epoch 9/20, Loss: 1.8380, Acc: 50.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_9.pth
# Epoch 10/20, Loss: 1.7601, Acc: 52.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_10.pth
# Epoch 11/20, Loss: 1.7150, Acc: 53.72%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_11.pth
# Epoch 12/20, Loss: 1.6580, Acc: 55.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_12.pth
# Epoch 13/20, Loss: 1.6089, Acc: 56.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_13.pth
# Epoch 14/20, Loss: 1.5668, Acc: 57.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_14.pth
# Epoch 15/20, Loss: 1.5207, Acc: 58.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_15.pth
# Epoch 16/20, Loss: 1.4880, Acc: 59.19%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_16.pth
# Epoch 17/20, Loss: 1.4540, Acc: 59.88%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_17.pth
# Epoch 18/20, Loss: 1.4207, Acc: 60.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_18.pth
# Epoch 19/20, Loss: 1.3897, Acc: 61.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_19.pth
# Epoch 20/20, Loss: 1.3687, Acc: 61.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_35_weights.pth
# Attempting to load model for exit layer 36
# Fine-tuning new model for exit layer 36
# Epoch 1/20, Loss: 4.6737, Acc: 12.00%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_1.pth
# Epoch 2/20, Loss: 3.0908, Acc: 27.74%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_2.pth
# Epoch 3/20, Loss: 2.6635, Acc: 34.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_3.pth
# Epoch 4/20, Loss: 2.4135, Acc: 39.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_4.pth
# Epoch 5/20, Loss: 2.2342, Acc: 42.89%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_5.pth
# Epoch 6/20, Loss: 2.0995, Acc: 45.33%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_6.pth
# Epoch 7/20, Loss: 1.9955, Acc: 47.63%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_7.pth
# Epoch 8/20, Loss: 1.9050, Acc: 49.60%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_8.pth
# Epoch 9/20, Loss: 1.8312, Acc: 51.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_9.pth
# Epoch 10/20, Loss: 1.7590, Acc: 52.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_10.pth
# Epoch 11/20, Loss: 1.7084, Acc: 53.99%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_11.pth
# Epoch 12/20, Loss: 1.6537, Acc: 55.31%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_12.pth
# Epoch 13/20, Loss: 1.6003, Acc: 56.58%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_13.pth
# Epoch 14/20, Loss: 1.5642, Acc: 57.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_14.pth
# Epoch 15/20, Loss: 1.5201, Acc: 58.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_15.pth
# Epoch 16/20, Loss: 1.4886, Acc: 59.14%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_16.pth
# Epoch 17/20, Loss: 1.4496, Acc: 60.21%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_17.pth
# Epoch 18/20, Loss: 1.4177, Acc: 61.02%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_18.pth
# Epoch 19/20, Loss: 1.3941, Acc: 61.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_19.pth
# Epoch 20/20, Loss: 1.3655, Acc: 62.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_36_weights.pth
# Attempting to load model for exit layer 37
# Fine-tuning new model for exit layer 37
# Epoch 1/20, Loss: 4.8785, Acc: 9.73%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_37_epoch_1.pth
# Epoch 2/20, Loss: 3.2686, Acc: 24.84%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_37_epoch_2.pth
# Epoch 3/20, Loss: 2.8032, Acc: 32.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_37_epoch_3.pth
# Epoch 4/20, Loss: 2.5473, Acc: 36.85%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_37_epoch_4.pth
# Epoch 5/20, Loss: 2.3629, Acc: 40.29%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_37_epoch_5.pth
# ...
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_7.pth
# Epoch 8/20, Loss: 2.3764, Acc: 40.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_8.pth
# Epoch 9/20, Loss: 2.2939, Acc: 41.70%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_9.pth
# Epoch 10/20, Loss: 2.2140, Acc: 43.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_10.pth
# Epoch 11/20, Loss: 2.1474, Acc: 44.39%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_11.pth
# Epoch 12/20, Loss: 2.0936, Acc: 45.37%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_12.pth
# Epoch 13/20, Loss: 2.0384, Acc: 46.49%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_13.pth
# Epoch 14/20, Loss: 1.9975, Acc: 47.45%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_14.pth
# Epoch 15/20, Loss: 1.9452, Acc: 48.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_15.pth
# Epoch 16/20, Loss: 1.9106, Acc: 49.28%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_16.pth
# Epoch 17/20, Loss: 1.8683, Acc: 50.31%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_17.pth
# Epoch 18/20, Loss: 1.8369, Acc: 51.02%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_18.pth
# Epoch 19/20, Loss: 1.8082, Acc: 51.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_19.pth
# Epoch 20/20, Loss: 1.7679, Acc: 52.50%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_51_weights.pth
# Attempting to load model for exit layer 52
# Fine-tuning new model for exit layer 52
# Epoch 1/20, Loss: 5.5976, Acc: 5.02%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_1.pth
# Epoch 2/20, Loss: 3.9693, Acc: 15.83%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_2.pth
# Epoch 3/20, Loss: 3.3724, Acc: 23.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_3.pth
# Epoch 4/20, Loss: 3.0374, Acc: 28.24%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_4.pth
# Epoch 5/20, Loss: 2.8212, Acc: 32.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_5.pth
# Epoch 6/20, Loss: 2.6666, Acc: 34.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_6.pth
# Epoch 7/20, Loss: 2.5306, Acc: 36.92%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_7.pth
# Epoch 8/20, Loss: 2.4339, Acc: 38.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_8.pth
# Epoch 9/20, Loss: 2.3486, Acc: 40.56%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_9.pth
# Epoch 10/20, Loss: 2.2715, Acc: 41.98%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_10.pth
# Epoch 11/20, Loss: 2.2047, Acc: 43.51%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_11.pth
# Epoch 12/20, Loss: 2.1478, Acc: 44.55%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_12.pth
# Epoch 13/20, Loss: 2.0943, Acc: 45.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_13.pth
# Epoch 14/20, Loss: 2.0498, Acc: 46.47%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_14.pth
# Epoch 15/20, Loss: 1.9997, Acc: 47.44%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_15.pth
# Epoch 16/20, Loss: 1.9550, Acc: 48.26%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_16.pth
# Epoch 17/20, Loss: 1.9138, Acc: 49.26%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_17.pth
# Epoch 18/20, Loss: 1.8966, Acc: 49.77%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_18.pth
# Epoch 19/20, Loss: 1.8580, Acc: 50.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_19.pth
# Epoch 20/20, Loss: 1.8293, Acc: 50.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_52_weights.pth
# Attempting to load model for exit layer 54
# Fine-tuning new model for exit layer 54
# Epoch 1/20, Loss: 5.7692, Acc: 4.76%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_1.pth
# Epoch 2/20, Loss: 3.9580, Acc: 15.71%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_2.pth
# Epoch 3/20, Loss: 3.3518, Acc: 23.73%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_3.pth
# Epoch 4/20, Loss: 3.0368, Acc: 28.81%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_4.pth
# Epoch 5/20, Loss: 2.8258, Acc: 31.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_5.pth
# Epoch 6/20, Loss: 2.6484, Acc: 35.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_6.pth
# Epoch 7/20, Loss: 2.5289, Acc: 37.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_7.pth
# Epoch 8/20, Loss: 2.4461, Acc: 38.89%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_8.pth
# Epoch 9/20, Loss: 2.3447, Acc: 40.53%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_9.pth
# Epoch 10/20, Loss: 2.2715, Acc: 42.11%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_10.pth
# Epoch 11/20, Loss: 2.2096, Acc: 43.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_11.pth
# Epoch 12/20, Loss: 2.1306, Acc: 44.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_12.pth
# Epoch 13/20, Loss: 2.0921, Acc: 45.75%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_13.pth
# Epoch 14/20, Loss: 2.0566, Acc: 46.68%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_14.pth
# Epoch 15/20, Loss: 1.9916, Acc: 47.90%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_15.pth
# Epoch 16/20, Loss: 1.9550, Acc: 48.66%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_16.pth
# Epoch 17/20, Loss: 1.9189, Acc: 49.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_17.pth
# Epoch 18/20, Loss: 1.8907, Acc: 50.00%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_18.pth
# Epoch 19/20, Loss: 1.8520, Acc: 50.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_19.pth
# Epoch 20/20, Loss: 1.8251, Acc: 51.20%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_54_weights.pth
# Attempting to load model for exit layer 68
# Fine-tuning new model for exit layer 68
# Epoch 1/20, Loss: 5.9815, Acc: 4.07%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_1.pth
# Epoch 2/20, Loss: 4.2105, Acc: 13.72%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_2.pth
# Epoch 3/20, Loss: 3.5928, Acc: 21.19%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_3.pth
# Epoch 4/20, Loss: 3.2724, Acc: 26.12%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_4.pth
# Epoch 5/20, Loss: 3.0336, Acc: 29.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_5.pth
# Epoch 6/20, Loss: 2.8601, Acc: 32.62%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_6.pth
# Epoch 7/20, Loss: 2.7367, Acc: 34.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_7.pth
# Epoch 8/20, Loss: 2.6303, Acc: 36.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_8.pth
# Epoch 9/20, Loss: 2.5539, Acc: 38.42%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_9.pth
# Epoch 10/20, Loss: 2.4548, Acc: 40.01%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_10.pth
# Epoch 11/20, Loss: 2.3980, Acc: 41.12%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_11.pth
# Epoch 12/20, Loss: 2.3512, Acc: 42.40%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_12.pth
# Epoch 13/20, Loss: 2.2950, Acc: 43.30%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_13.pth
# Epoch 14/20, Loss: 2.2429, Acc: 44.42%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_14.pth
# Epoch 15/20, Loss: 2.1949, Acc: 45.63%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_15.pth
# Epoch 16/20, Loss: 2.1620, Acc: 45.82%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_16.pth
# Epoch 17/20, Loss: 2.1210, Acc: 46.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_17.pth
# Epoch 18/20, Loss: 2.0830, Acc: 47.69%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_18.pth
# Epoch 19/20, Loss: 2.0421, Acc: 48.36%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_19.pth
# Epoch 20/20, Loss: 2.0113, Acc: 48.91%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_68_weights.pth
# Attempting to load model for exit layer 69
# Fine-tuning new model for exit layer 69
# Epoch 1/20, Loss: 6.0566, Acc: 4.17%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_1.pth
# Epoch 2/20, Loss: 4.2526, Acc: 13.52%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_2.pth
# Epoch 3/20, Loss: 3.6367, Acc: 20.95%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_3.pth
# Epoch 4/20, Loss: 3.2839, Acc: 26.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_4.pth
# Epoch 5/20, Loss: 3.0290, Acc: 29.81%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_5.pth
# Epoch 6/20, Loss: 2.8900, Acc: 32.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_6.pth
# Epoch 7/20, Loss: 2.7586, Acc: 34.81%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_7.pth
# Epoch 8/20, Loss: 2.6320, Acc: 36.87%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_8.pth
# Epoch 9/20, Loss: 2.5478, Acc: 38.50%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_9.pth
# Epoch 10/20, Loss: 2.4766, Acc: 39.58%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_10.pth
# Epoch 11/20, Loss: 2.4074, Acc: 41.07%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_11.pth
# Epoch 12/20, Loss: 2.3539, Acc: 42.15%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_12.pth
# Epoch 13/20, Loss: 2.2798, Acc: 43.38%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_13.pth
# Epoch 14/20, Loss: 2.2523, Acc: 43.94%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_14.pth
# Epoch 15/20, Loss: 2.1998, Acc: 45.06%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_15.pth
# Epoch 16/20, Loss: 2.1489, Acc: 45.97%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_16.pth
# Epoch 17/20, Loss: 2.1341, Acc: 46.60%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_17.pth
# Epoch 18/20, Loss: 2.0901, Acc: 47.48%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_18.pth
# Epoch 19/20, Loss: 2.0547, Acc: 47.89%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_19.pth
# Epoch 20/20, Loss: 2.0170, Acc: 48.80%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_69_weights.pth
# Attempting to load model for exit layer 70
# Fine-tuning new model for exit layer 70
# Epoch 1/20, Loss: 6.1018, Acc: 4.32%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_1.pth
# Epoch 2/20, Loss: 4.2665, Acc: 13.57%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_2.pth
# Epoch 3/20, Loss: 3.6549, Acc: 20.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_3.pth
# Epoch 4/20, Loss: 3.3300, Acc: 25.76%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_4.pth
# Epoch 5/20, Loss: 3.1001, Acc: 29.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_5.pth
# Epoch 6/20, Loss: 2.9155, Acc: 32.05%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_6.pth
# Epoch 7/20, Loss: 2.7841, Acc: 34.65%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_7.pth
# Epoch 8/20, Loss: 2.6832, Acc: 36.56%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_8.pth
# Epoch 9/20, Loss: 2.5962, Acc: 38.28%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_9.pth
# Epoch 10/20, Loss: 2.5139, Acc: 39.75%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_10.pth
# Epoch 11/20, Loss: 2.4538, Acc: 40.67%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_11.pth
# Epoch 12/20, Loss: 2.3987, Acc: 42.09%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_12.pth
# Epoch 13/20, Loss: 2.3464, Acc: 42.99%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_13.pth
# Epoch 14/20, Loss: 2.2841, Acc: 44.08%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_14.pth
# Epoch 15/20, Loss: 2.2458, Acc: 44.78%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_15.pth
# Epoch 16/20, Loss: 2.2117, Acc: 45.59%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_16.pth
# Epoch 17/20, Loss: 2.1551, Acc: 46.63%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_17.pth
# Epoch 18/20, Loss: 2.1316, Acc: 47.26%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_18.pth
# Epoch 19/20, Loss: 2.1032, Acc: 47.79%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_19.pth
# Epoch 20/20, Loss: 2.0786, Acc: 48.44%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_epoch_20.pth
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_70_weights.pth
# Attempting to load model for exit layer 71
# Fine-tuning new model for exit layer 71
# Epoch 1/20, Loss: 5.9891, Acc: 4.30%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_71_epoch_1.pth
# Epoch 2/20, Loss: 4.2572, Acc: 13.99%
# Model saved to /content/gdrive/My Drive/checkpoints/early_exit_models/exit_71_epoch_2.pth

# %%
import numpy as np

resnet_predictions = {}
test_labels = None  # Will store labels (assumed to be the same for both)

resnet_variants = [18, 101]

for variant in resnet_variants:
    trainer = ResNetTrainer(variant, epochs=20, batch_size=128, save_path=f"/content/gdrive/My Drive/checkpoints/resnet{variant}_cifar100")
    trainer.train()
    trainer.load_model(exact_checkpoint=100)

    test_loader = DataLoader(trainer.testset, batch_size=128, shuffle=False, num_workers=2)
    complexity_calculator = ComplexityCalculator(trainer.model, test_loader, trainer.device)
    _, confidences, predictions, test_images, test_labels = complexity_calculator.compute_complexities()

    resnet_predictions[variant] = np.array(predictions)  # Store predictions

test_labels = np.array(test_labels)  # Store ground truth

# Ensure both models have the same number of predictions
assert resnet_predictions[18].shape == resnet_predictions[101].shape == test_labels.shape

# Correct classifications
correct_18 = resnet_predictions[18] == test_labels
correct_101 = resnet_predictions[101] == test_labels

# Category classification
correct_both = correct_18 & correct_101
wrong_both = ~correct_18 & ~correct_101
correct_18_wrong_101 = correct_18 & ~correct_101
correct_101_wrong_18 = correct_101 & ~correct_18

# Count occurrences
print(f"Correct in both: {correct_both.sum()}")
print(f"Wrong in both: {wrong_both.sum()}")
print(f"Correct in ResNet-18 but wrong in ResNet-101: {correct_18_wrong_101.sum()}")
print(f"Correct in ResNet-101 but wrong in ResNet-18: {correct_101_wrong_18.sum()}")

# %%
resnet_variants = [18, 34, 50]

for variant in resnet_variants:
    trainer = ResNetTrainer(variant, epochs=20, batch_size=128, save_path=f"/content/gdrive/My Drive/checkpoints/resnet{variant}_cifar100")
    trainer.train()
    trainer.load_model(exact_checkpoint=50)

    test_loader = DataLoader(trainer.testset, batch_size=128, shuffle=False, num_workers=2)
    complexity_calculator = ComplexityCalculator(trainer.model, test_loader, trainer.device)
    complexities, confidences, predictions, test_images, test_labels = complexity_calculator.compute_complexities()

    complexities = np.array(complexities)

    # Plot histogram
    plt.figure(figsize=(10, 5))
    sns.histplot(complexities, bins=50, kde=True)
    plt.xlabel("Complexity Score")
    plt.ylabel("Frequency")
    plt.title(f"Distribution of Photo Complexities in resnet{variant}")
    plt.show()
